# %%
import os
import pandas as pd

# %% [markdown]
# ## load data from combined csv created from 'Barchart_combinorator.py'

# %%
final_combined_data = pd.read_csv('BarchartFutures/final_combined.csv')

# %%
final_combined_data['Time'] = pd.to_datetime(final_combined_data['Time'], errors='coerce')
final_combined_data.rename(columns={'Time': 'Date'}, inplace=True)
final_combined_data['day_of_week'] = final_combined_data['Date'].dt.weekday

# %%
grouped = final_combined_data.groupby('Futures_Contract_Type')

# Step 4: Loop through each group (Futures_Contract_Type) and check for missing Wednesdays
for contract_type, group in grouped:
    # Filter for Wednesdays (day_of_week == 2) in the group
    wednesday_data = group[group['day_of_week'] == 2]
    
    # Generate the full range of Wednesdays within the date range of this contract type
    date_range = pd.date_range(start=group['Date'].min(), end=group['Date'].max(), freq='W-WED')
    
    # Compare expected number of Wednesdays with actual number of Wednesdays
    expected_wednesdays = len(date_range)
    actual_wednesdays = len(wednesday_data)

    # Check for missing Wednesdays
    if expected_wednesdays != actual_wednesdays:
        missing_wednesdays = date_range[~date_range.isin(wednesday_data['Date'])]
        print(f"Futures_Contract_Type: {contract_type}")
        print(f"Missing Wednesday data points: {missing_wednesdays}")
        
        # Step 5: Loop through each missing Wednesday and find the surrounding Tuesday and Thursday
        for missing_wed in missing_wednesdays:
            # Find the corresponding Tuesday and Thursday
            tuesday = missing_wed - pd.Timedelta(days=1)
            thursday = missing_wed + pd.Timedelta(days=1)

            # Get the rows for Tuesday and Thursday (if they exist in the data)
            tuesday_data = group[group['Date'] == tuesday]
            thursday_data = group[group['Date'] == thursday]

            if not tuesday_data.empty and not thursday_data.empty:
                # Select only numeric columns for averaging
                numeric_columns = group.select_dtypes(include=['float64', 'int64']).columns
                # print(numeric_columns)
                avg_data = (tuesday_data[numeric_columns].iloc[0] + thursday_data[numeric_columns].iloc[0]) / 2

                # Create a new row with the calculated average
                new_row = pd.Series(avg_data)
            
                # Set the missing Wednesday's date and day_of_week in the new row
                new_row['Date'] = missing_wed
                new_row['Futures_Contract_Type'] = contract_type
                new_row['day_of_week'] = 2  # Set day_of_week to Wednesday
                new_row = new_row.reindex(final_combined_data.columns)
                # Append the interpolated data to the original dataframe
                final_combined_data = pd.concat([final_combined_data, new_row.to_frame().T], ignore_index=True)
                print(f'interpolated data added for {missing_wed}')
            else:
                print(f"Tuesday or Thursday missing for: {missing_wed}")
    else:
        print(f"Futures_Contract_Type: {contract_type} - No missing Wednesday data points.")

# Sort the final dataframe to keep it in order
final_combined_data.sort_values(by=['Futures_Contract_Type', 'Date'], inplace=True)
# Out:
# Futures_Contract_Type: KEH05
# Missing Wednesday data points: DatetimeIndex(['2004-12-01', '2004-12-08'], dtype='datetime64[ns]', freq='W-WED')
# Tuesday or Thursday missing for: 2004-12-01 00:00:00
# Tuesday or Thursday missing for: 2004-12-08 00:00:00
# Futures_Contract_Type: KEH06 - No missing Wednesday data points.
# Futures_Contract_Type: KEH07 - No missing Wednesday data points.
# Futures_Contract_Type: KEH08
# Missing Wednesday data points: DatetimeIndex(['2007-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2007-07-04 00:00:00
# Futures_Contract_Type: KEH09
# Missing Wednesday data points: DatetimeIndex(['2007-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2007-07-04 00:00:00
# Futures_Contract_Type: KEH10 - No missing Wednesday data points.
# Futures_Contract_Type: KEH11 - No missing Wednesday data points.
# Futures_Contract_Type: KEH12 - No missing Wednesday data points.
# Futures_Contract_Type: KEH13
# Missing Wednesday data points: DatetimeIndex(['2012-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2012-07-04 00:00:00
# Futures_Contract_Type: KEH14
# Missing Wednesday data points: DatetimeIndex(['2012-07-04', '2013-12-25', '2014-01-01'], dtype='datetime64[ns]', freq=None)
# interpolated data added for 2012-07-04 00:00:00
# interpolated data added for 2013-12-25 00:00:00
# interpolated data added for 2014-01-01 00:00:00
# Futures_Contract_Type: KEH15
# Missing Wednesday data points: DatetimeIndex(['2013-12-25', '2014-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2013-12-25 00:00:00
# interpolated data added for 2014-01-01 00:00:00
# Futures_Contract_Type: KEH16
# Missing Wednesday data points: DatetimeIndex(['2013-12-25', '2014-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2013-12-25 00:00:00
# interpolated data added for 2014-01-01 00:00:00
# Futures_Contract_Type: KEH17 - No missing Wednesday data points.
# Futures_Contract_Type: KEH18 - No missing Wednesday data points.
# Futures_Contract_Type: KEH19
# Missing Wednesday data points: DatetimeIndex(['2018-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2018-07-04 00:00:00
# Futures_Contract_Type: KEH20
# Missing Wednesday data points: DatetimeIndex(['2018-07-04', '2019-12-25', '2020-01-01'], dtype='datetime64[ns]', freq=None)
# interpolated data added for 2018-07-04 00:00:00
# interpolated data added for 2019-12-25 00:00:00
# interpolated data added for 2020-01-01 00:00:00
# Futures_Contract_Type: KEH21
# Missing Wednesday data points: DatetimeIndex(['2019-12-25', '2020-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2019-12-25 00:00:00
# interpolated data added for 2020-01-01 00:00:00
# Futures_Contract_Type: KEH22
# Missing Wednesday data points: DatetimeIndex(['2019-12-25', '2020-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2019-12-25 00:00:00
# interpolated data added for 2020-01-01 00:00:00
# Futures_Contract_Type: KEH23 - No missing Wednesday data points.
# Futures_Contract_Type: KEH24 - No missing Wednesday data points.
# Futures_Contract_Type: KEH25
# Missing Wednesday data points: DatetimeIndex(['2024-06-19'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2024-06-19 00:00:00
# Futures_Contract_Type: KEH26
# Missing Wednesday data points: DatetimeIndex(['2024-06-19'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2024-06-19 00:00:00
# Futures_Contract_Type: KEH27 - No missing Wednesday data points.
# Futures_Contract_Type: KEK05
# Missing Wednesday data points: DatetimeIndex(['2004-12-01', '2004-12-08'], dtype='datetime64[ns]', freq='W-WED')
# Tuesday or Thursday missing for: 2004-12-01 00:00:00
# Tuesday or Thursday missing for: 2004-12-08 00:00:00
# Futures_Contract_Type: KEK06 - No missing Wednesday data points.
# Futures_Contract_Type: KEK07 - No missing Wednesday data points.
# Futures_Contract_Type: KEK08
# Missing Wednesday data points: DatetimeIndex(['2007-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2007-07-04 00:00:00
# Futures_Contract_Type: KEK09 - No missing Wednesday data points.
# Futures_Contract_Type: KEK10 - No missing Wednesday data points.
# Futures_Contract_Type: KEK11 - No missing Wednesday data points.
# Futures_Contract_Type: KEK12 - No missing Wednesday data points.
# Futures_Contract_Type: KEK14
# Missing Wednesday data points: DatetimeIndex(['2012-07-04', '2013-12-25', '2014-01-01'], dtype='datetime64[ns]', freq=None)
# interpolated data added for 2012-07-04 00:00:00
# interpolated data added for 2013-12-25 00:00:00
# interpolated data added for 2014-01-01 00:00:00
# Futures_Contract_Type: KEK15
# Missing Wednesday data points: DatetimeIndex(['2013-12-25', '2014-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2013-12-25 00:00:00
# interpolated data added for 2014-01-01 00:00:00
# Futures_Contract_Type: KEK16
# Missing Wednesday data points: DatetimeIndex(['2013-12-25', '2014-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2013-12-25 00:00:00
# interpolated data added for 2014-01-01 00:00:00
# Futures_Contract_Type: KEK17 - No missing Wednesday data points.
# Futures_Contract_Type: KEK18 - No missing Wednesday data points.
# Futures_Contract_Type: KEK19
# Missing Wednesday data points: DatetimeIndex(['2018-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2018-07-04 00:00:00
# Futures_Contract_Type: KEK20
# Missing Wednesday data points: DatetimeIndex(['2018-07-04', '2019-12-25', '2020-01-01'], dtype='datetime64[ns]', freq=None)
# interpolated data added for 2018-07-04 00:00:00
# interpolated data added for 2019-12-25 00:00:00
# interpolated data added for 2020-01-01 00:00:00
# Futures_Contract_Type: KEK21
# Missing Wednesday data points: DatetimeIndex(['2019-12-25', '2020-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2019-12-25 00:00:00
# interpolated data added for 2020-01-01 00:00:00
# Futures_Contract_Type: KEK22
# Missing Wednesday data points: DatetimeIndex(['2019-12-25', '2020-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2019-12-25 00:00:00
# interpolated data added for 2020-01-01 00:00:00
# Futures_Contract_Type: KEK23 - No missing Wednesday data points.
# Futures_Contract_Type: KEK24 - No missing Wednesday data points.
# Futures_Contract_Type: KEK25
# Missing Wednesday data points: DatetimeIndex(['2024-06-19'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2024-06-19 00:00:00
# Futures_Contract_Type: KEK26
# Missing Wednesday data points: DatetimeIndex(['2024-06-19'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2024-06-19 00:00:00
# Futures_Contract_Type: KEK27 - No missing Wednesday data points.
# Futures_Contract_Type: KEN05
# Missing Wednesday data points: DatetimeIndex(['2004-12-01', '2004-12-08'], dtype='datetime64[ns]', freq='W-WED')
# Tuesday or Thursday missing for: 2004-12-01 00:00:00
# Tuesday or Thursday missing for: 2004-12-08 00:00:00
# Futures_Contract_Type: KEN06 - No missing Wednesday data points.
# Futures_Contract_Type: KEN07
# Missing Wednesday data points: DatetimeIndex(['2007-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2007-07-04 00:00:00
# Futures_Contract_Type: KEN08
# Missing Wednesday data points: DatetimeIndex(['2007-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2007-07-04 00:00:00
# Futures_Contract_Type: KEN09
# Missing Wednesday data points: DatetimeIndex(['2007-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2007-07-04 00:00:00
# Futures_Contract_Type: KEN10 - No missing Wednesday data points.
# Futures_Contract_Type: KEN11 - No missing Wednesday data points.
# Futures_Contract_Type: KEN12
# Missing Wednesday data points: DatetimeIndex(['2012-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2012-07-04 00:00:00
# Futures_Contract_Type: KEN13
# Missing Wednesday data points: DatetimeIndex(['2012-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2012-07-04 00:00:00
# Futures_Contract_Type: KEN14
# Missing Wednesday data points: DatetimeIndex(['2012-07-04', '2013-12-25', '2014-01-01'], dtype='datetime64[ns]', freq=None)
# interpolated data added for 2012-07-04 00:00:00
# interpolated data added for 2013-12-25 00:00:00
# interpolated data added for 2014-01-01 00:00:00
# Futures_Contract_Type: KEN15
# Missing Wednesday data points: DatetimeIndex(['2013-12-25', '2014-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2013-12-25 00:00:00
# interpolated data added for 2014-01-01 00:00:00
# Futures_Contract_Type: KEN16
# Missing Wednesday data points: DatetimeIndex(['2013-12-25', '2014-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2013-12-25 00:00:00
# interpolated data added for 2014-01-01 00:00:00
# Futures_Contract_Type: KEN17 - No missing Wednesday data points.
# Futures_Contract_Type: KEN18
# Missing Wednesday data points: DatetimeIndex(['2018-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2018-07-04 00:00:00
# Futures_Contract_Type: KEN19
# Missing Wednesday data points: DatetimeIndex(['2018-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2018-07-04 00:00:00
# Futures_Contract_Type: KEN20
# Missing Wednesday data points: DatetimeIndex(['2018-07-04', '2019-12-25', '2020-01-01'], dtype='datetime64[ns]', freq=None)
# interpolated data added for 2018-07-04 00:00:00
# interpolated data added for 2019-12-25 00:00:00
# interpolated data added for 2020-01-01 00:00:00
# Futures_Contract_Type: KEN21
# Missing Wednesday data points: DatetimeIndex(['2019-12-25', '2020-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2019-12-25 00:00:00
# interpolated data added for 2020-01-01 00:00:00
# Futures_Contract_Type: KEN22
# Missing Wednesday data points: DatetimeIndex(['2019-12-25', '2020-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2019-12-25 00:00:00
# interpolated data added for 2020-01-01 00:00:00
# Futures_Contract_Type: KEN23 - No missing Wednesday data points.
# Futures_Contract_Type: KEN24
# Missing Wednesday data points: DatetimeIndex(['2024-06-19'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2024-06-19 00:00:00
# Futures_Contract_Type: KEN25
# Missing Wednesday data points: DatetimeIndex(['2024-06-19'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2024-06-19 00:00:00
# Futures_Contract_Type: KEN26
# Missing Wednesday data points: DatetimeIndex(['2024-06-19'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2024-06-19 00:00:00
# Futures_Contract_Type: KEN27 - No missing Wednesday data points.
# Futures_Contract_Type: KEU05
# Missing Wednesday data points: DatetimeIndex(['2004-12-01', '2004-12-08'], dtype='datetime64[ns]', freq='W-WED')
# Tuesday or Thursday missing for: 2004-12-01 00:00:00
# Tuesday or Thursday missing for: 2004-12-08 00:00:00
# Futures_Contract_Type: KEU06 - No missing Wednesday data points.
# Futures_Contract_Type: KEU07
# Missing Wednesday data points: DatetimeIndex(['2007-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2007-07-04 00:00:00
# Futures_Contract_Type: KEU08
# Missing Wednesday data points: DatetimeIndex(['2007-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2007-07-04 00:00:00
# Futures_Contract_Type: KEU09 - No missing Wednesday data points.
# Futures_Contract_Type: KEU10 - No missing Wednesday data points.
# Futures_Contract_Type: KEU11 - No missing Wednesday data points.
# Futures_Contract_Type: KEU12
# Missing Wednesday data points: DatetimeIndex(['2012-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2012-07-04 00:00:00
# Futures_Contract_Type: KEU13
# Missing Wednesday data points: DatetimeIndex(['2012-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2012-07-04 00:00:00
# Futures_Contract_Type: KEU14
# Missing Wednesday data points: DatetimeIndex(['2013-12-25', '2014-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2013-12-25 00:00:00
# interpolated data added for 2014-01-01 00:00:00
# Futures_Contract_Type: KEU15
# Missing Wednesday data points: DatetimeIndex(['2013-12-25', '2014-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2013-12-25 00:00:00
# interpolated data added for 2014-01-01 00:00:00
# Futures_Contract_Type: KEU16 - No missing Wednesday data points.
# Futures_Contract_Type: KEU17 - No missing Wednesday data points.
# Futures_Contract_Type: KEU18
# Missing Wednesday data points: DatetimeIndex(['2018-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2018-07-04 00:00:00
# Futures_Contract_Type: KEU19
# Missing Wednesday data points: DatetimeIndex(['2018-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2018-07-04 00:00:00
# Futures_Contract_Type: KEU20
# Missing Wednesday data points: DatetimeIndex(['2019-12-25', '2020-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2019-12-25 00:00:00
# interpolated data added for 2020-01-01 00:00:00
# Futures_Contract_Type: KEU21
# Missing Wednesday data points: DatetimeIndex(['2019-12-25', '2020-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2019-12-25 00:00:00
# interpolated data added for 2020-01-01 00:00:00
# Futures_Contract_Type: KEU22 - No missing Wednesday data points.
# Futures_Contract_Type: KEU23 - No missing Wednesday data points.
# Futures_Contract_Type: KEU24
# Missing Wednesday data points: DatetimeIndex(['2024-06-19'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2024-06-19 00:00:00
# Futures_Contract_Type: KEU25
# Missing Wednesday data points: DatetimeIndex(['2024-06-19'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2024-06-19 00:00:00
# Futures_Contract_Type: KEU26 - No missing Wednesday data points.
# Futures_Contract_Type: KEZ04
# Missing Wednesday data points: DatetimeIndex(['2004-12-01', '2004-12-08'], dtype='datetime64[ns]', freq='W-WED')
# Tuesday or Thursday missing for: 2004-12-01 00:00:00
# Tuesday or Thursday missing for: 2004-12-08 00:00:00
# Futures_Contract_Type: KEZ05
# Missing Wednesday data points: DatetimeIndex(['2004-12-01', '2004-12-08'], dtype='datetime64[ns]', freq='W-WED')
# Tuesday or Thursday missing for: 2004-12-01 00:00:00
# Tuesday or Thursday missing for: 2004-12-08 00:00:00
# Futures_Contract_Type: KEZ06 - No missing Wednesday data points.
# Futures_Contract_Type: KEZ07
# Missing Wednesday data points: DatetimeIndex(['2007-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2007-07-04 00:00:00
# Futures_Contract_Type: KEZ08
# Missing Wednesday data points: DatetimeIndex(['2007-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2007-07-04 00:00:00
# Futures_Contract_Type: KEZ09
# Missing Wednesday data points: DatetimeIndex(['2007-09-05', '2007-09-12', '2007-09-19', '2007-10-03'], dtype='datetime64[ns]', freq=None)
# Tuesday or Thursday missing for: 2007-09-05 00:00:00
# Tuesday or Thursday missing for: 2007-09-12 00:00:00
# Tuesday or Thursday missing for: 2007-09-19 00:00:00
# Tuesday or Thursday missing for: 2007-10-03 00:00:00
# Futures_Contract_Type: KEZ10 - No missing Wednesday data points.
# Futures_Contract_Type: KEZ11 - No missing Wednesday data points.
# Futures_Contract_Type: KEZ12
# Missing Wednesday data points: DatetimeIndex(['2012-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2012-07-04 00:00:00
# Futures_Contract_Type: KEZ13
# Missing Wednesday data points: DatetimeIndex(['2012-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2012-07-04 00:00:00
# Futures_Contract_Type: KEZ14
# Missing Wednesday data points: DatetimeIndex(['2013-12-25', '2014-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2013-12-25 00:00:00
# interpolated data added for 2014-01-01 00:00:00
# Futures_Contract_Type: KEZ15
# Missing Wednesday data points: DatetimeIndex(['2013-12-25', '2014-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2013-12-25 00:00:00
# interpolated data added for 2014-01-01 00:00:00
# Futures_Contract_Type: KEZ16 - No missing Wednesday data points.
# Futures_Contract_Type: KEZ17 - No missing Wednesday data points.
# Futures_Contract_Type: KEZ18
# Missing Wednesday data points: DatetimeIndex(['2018-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2018-07-04 00:00:00
# Futures_Contract_Type: KEZ19
# Missing Wednesday data points: DatetimeIndex(['2018-07-04'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2018-07-04 00:00:00
# Futures_Contract_Type: KEZ20
# Missing Wednesday data points: DatetimeIndex(['2019-12-25', '2020-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2019-12-25 00:00:00
# interpolated data added for 2020-01-01 00:00:00
# Futures_Contract_Type: KEZ21
# Missing Wednesday data points: DatetimeIndex(['2019-12-25', '2020-01-01'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2019-12-25 00:00:00
# interpolated data added for 2020-01-01 00:00:00
# Futures_Contract_Type: KEZ22 - No missing Wednesday data points.
# Futures_Contract_Type: KEZ23 - No missing Wednesday data points.
# Futures_Contract_Type: KEZ24
# Missing Wednesday data points: DatetimeIndex(['2024-06-19'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2024-06-19 00:00:00
# Futures_Contract_Type: KEZ25
# Missing Wednesday data points: DatetimeIndex(['2024-06-19'], dtype='datetime64[ns]', freq='W-WED')
# interpolated data added for 2024-06-19 00:00:00
# Futures_Contract_Type: KEZ26 - No missing Wednesday data points.

# %%
barchart_wednesdays = final_combined_data.loc[(final_combined_data['day_of_week'] == 2)].reset_index(drop=True)
barchart_wednesdays
# Out:
#       Futures_Contract_Type                 Date    Open    High     Low  \
# 0                     KEH05  2003-11-12 00:00:00   374.0   374.0   374.0
# 1                     KEH05  2003-11-19 00:00:00   374.0   374.0   374.0
# 2                     KEH05  2003-11-26 00:00:00   374.0   374.0   374.0
# 3                     KEH05  2003-12-03 00:00:00   390.0   390.0   390.0
# 4                     KEH05  2003-12-10 00:00:00   393.0   393.0   383.0
# ...                     ...                  ...     ...     ...     ...
# 11908                 KEZ26  2024-08-07 00:00:00  636.75  636.75  636.75
# 11909                 KEZ26  2024-08-14 00:00:00   628.0   628.0   628.0
# 11910                 KEZ26  2024-08-21 00:00:00  625.25  625.25  625.25
# 11911                 KEZ26  2024-08-28 00:00:00  627.25  627.25  627.25
# 11912                 KEZ26  2024-09-04 00:00:00  661.25  661.25  661.25
#
#          Last Change    %Chg Volume Open Int day_of_week
# 0       374.0    0.0   0.00%    0.0      1.0         2.0
# 1       374.0    0.0   0.00%    0.0      1.0         2.0
# 2       374.0    0.0   0.00%    0.0      1.0         2.0
# 3       390.0    5.0  +1.30%    0.0      1.0         2.0
# 4       393.0    0.0   0.00%    0.0      1.0         2.0
# ...       ...    ...     ...    ...      ...         ...
# 11908  636.75  -0.75  -0.12%    0.0      0.0         2.0
# 11909   628.0  -0.75  -0.12%    0.0      0.0         2.0
# 11910  625.25  -8.25  -1.30%    0.0      0.0         2.0
# 11911  627.25  10.25  +1.66%    0.0      0.0         2.0
# 11912  661.25  15.25  +2.36%    0.0      0.0         2.0
#
# [11913 rows x 11 columns]

# %%
contract_month_mapping = {
    'KEU': 9,  # September
    'KEZ': 12, # December
    'KEH': 3,  # March
    'KEK': 5,  # May
    'KEN': 7   # July
}

# Convert the 'Date' column to datetime if it's not already
barchart_wednesdays['Date'] = pd.to_datetime(barchart_wednesdays['Date'])

# Function to get the month and year from a Futures_Contract_Type
def get_contract_month_and_year(futures_contract_type):
    # Extract the prefix (first 3 characters) and year (last 2 characters)
    prefix = futures_contract_type[:3]
    year = '20' + futures_contract_type[3:]  # Assume year is 20XX

    # Get the month from the mapping
    month = contract_month_mapping.get(prefix)
    return int(month), int(year)
barchart_wednesdays[['contract_month','contract_year']] = barchart_wednesdays['Futures_Contract_Type'].apply(lambda x: pd.Series(get_contract_month_and_year(x)))
# Filter the DataFrame: Exclude rows where the contract is "up"
def exclude_up_contracts(row):
    futures_contract_type = row['Futures_Contract_Type']
    contract_month, contract_year = get_contract_month_and_year(futures_contract_type)

    # Check if the Date matches the contract month and year
    return not ((row['Date'].month == contract_month) & (row['Date'].year == contract_year))

# Apply the filter to exclude rows where contracts are "up"
barchart_wednesdays_filtered = barchart_wednesdays[barchart_wednesdays.apply(exclude_up_contracts, axis=1)]
barchart_wednesdays_filtered
# Out:
#       Futures_Contract_Type       Date    Open    High     Low    Last Change  \
# 0                     KEH05 2003-11-12   374.0   374.0   374.0   374.0    0.0
# 1                     KEH05 2003-11-19   374.0   374.0   374.0   374.0    0.0
# 2                     KEH05 2003-11-26   374.0   374.0   374.0   374.0    0.0
# 3                     KEH05 2003-12-03   390.0   390.0   390.0   390.0    5.0
# 4                     KEH05 2003-12-10   393.0   393.0   383.0   393.0    0.0
# ...                     ...        ...     ...     ...     ...     ...    ...
# 11908                 KEZ26 2024-08-07  636.75  636.75  636.75  636.75  -0.75
# 11909                 KEZ26 2024-08-14   628.0   628.0   628.0   628.0  -0.75
# 11910                 KEZ26 2024-08-21  625.25  625.25  625.25  625.25  -8.25
# 11911                 KEZ26 2024-08-28  627.25  627.25  627.25  627.25  10.25
# 11912                 KEZ26 2024-09-04  661.25  661.25  661.25  661.25  15.25
#
#          %Chg Volume Open Int day_of_week  contract_month  contract_year
# 0       0.00%    0.0      1.0         2.0               3           2005
# 1       0.00%    0.0      1.0         2.0               3           2005
# 2       0.00%    0.0      1.0         2.0               3           2005
# 3      +1.30%    0.0      1.0         2.0               3           2005
# 4       0.00%    0.0      1.0         2.0               3           2005
# ...       ...    ...      ...         ...             ...            ...
# 11908  -0.12%    0.0      0.0         2.0              12           2026
# 11909  -0.12%    0.0      0.0         2.0              12           2026
# 11910  -1.30%    0.0      0.0         2.0              12           2026
# 11911  +1.66%    0.0      0.0         2.0              12           2026
# 11912  +2.36%    0.0      0.0         2.0              12           2026
#
# [11718 rows x 13 columns]

# %%
barchart_wednesdays_filtered.to_csv('BarchartFutures/barchart_wednesdays.csv', index=False)
